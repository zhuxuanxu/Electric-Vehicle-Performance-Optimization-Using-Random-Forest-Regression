# %%
import pandas as pd
import numpy as np
import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#HongKong 2017-2018
hk17fp1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Hong Kong/FP1/23_Analysis_Non Qualifying Practice 1.CSV',delimiter=';')
hk17fp2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Hong Kong/FP2/23_Analysis_Non Qualifying Practice 2.CSV',delimiter=';')
hk17qg1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Hong Kong/Q/23_Analysis_Qualifying 1 Group 1.CSV',delimiter=';')
hk17qg2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Hong Kong/Q/23_Analysis_Qualifying 1 Group 2.CSV',delimiter=';')
hk17qg3 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Hong Kong/Q/23_Analysis_Qualifying 1 Group 3.CSV',delimiter=';')
hk17qg4 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Hong Kong/Q/23_Analysis_Qualifying 1 Group 4.CSV',delimiter=';')
hk17qsuperpole = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Hong Kong/Q/23_Analysis_Super Pole 1.CSV',delimiter=';')
hk17classrace = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Hong Kong/Race/03_Classification_Race 1 (3).CSV',delimiter=';')
hk17ranalysis = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Hong Kong/Race/23_Analysis_Race 1 (3).CSV',delimiter=';')

# %%
#HongKong2 2017-2018
hk217fp1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Hong Kong2/FP1/23_Analysis_Non Qualifying Practice 3.CSV',delimiter=';')
hk217qg1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Hong Kong2/Q/23_Analysis_Qualifying 2 Group 1.CSV',delimiter=';')
hk217qg2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Hong Kong2/Q/23_Analysis_Qualifying 2 Group 2.CSV',delimiter=';')
hk217qg3 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Hong Kong2/Q/23_Analysis_Qualifying 2 Group 3.CSV',delimiter=';')
hk217qg4 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Hong Kong2/Q/23_Analysis_Qualifying 2 Group 4.CSV',delimiter=';')
hk217qsuperpole = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Hong Kong2/Q/23_Analysis_Super Pole 2.CSV',delimiter=';')
hk217classrace = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Hong Kong2/Race/03_Classification_Race 2 (3).CSV',delimiter=';')
hk217ranalysis = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Hong Kong2/Race/23_Analysis_Race 2 (3).CSV',delimiter=';')

# %%
#HongKong 2016-2017
hk16fp1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/HongKong/FP1/23_Analysis_Non Qualifying Practice 1.CSV',delimiter=';')
hk16fp2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/HongKong/FP2/23_Analysis_Non Qualifying Practice 2.CSV',delimiter=';')
hk16qg1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/HongKong/Q/23_Analysis_Groups Qualifying Session.CSV',delimiter=';')
hk16classrace = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/HongKong/Race/03_Classification_Race (23).CSV',delimiter=';')
hk16ranalysis = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/HongKong/Race/23_Analysis_Race (22).CSV',delimiter=';')

# %%
#Weather HongKong 2016-2017
w_hk16qg1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/HongKong/Q/26_Weather_Groups Qualifying Session.CSV',delimiter=';')
w_hk16rrace = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/HongKong/Race/26_Weather_Race.CSV',delimiter=';')

# %%
#Weather HongKong 2017-2018
w_hk17qg1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Hong Kong/Q/26_Weather_Qualifying 1 Group 1.CSV',delimiter=';')
w_hk17qg2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Hong Kong/Q/26_Weather_Qualifying 1 Group 2.CSV',delimiter=';')
w_hk17qg3 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Hong Kong/Q/26_Weather_Qualifying 1 Group 3.CSV',delimiter=';')
w_hk17qg4 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Hong Kong/Q/26_Weather_Qualifying 1 Group 4.CSV',delimiter=';')
w_hk17qsuperpole = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Hong Kong/Q/26_Weather_Super Pole 1.CSV',delimiter=';')
w_hk17rrace = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Hong Kong/Race/26_Weather_Race 1.CSV',delimiter=';')

# %%
#Wether HongKong2 2017-2018
w_hk217qg1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Hong Kong2/Q/26_Weather_Qualifying 2 Group 1.CSV',delimiter=';')
w_hk217qg2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Hong Kong2/Q/26_Weather_Qualifying 2 Group 2.CSV',delimiter=';')
w_hk217qg3 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Hong Kong2/Q/26_Weather_Qualifying 2 Group 3.CSV',delimiter=';')
w_hk217qg4 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Hong Kong2/Q/26_Weather_Qualifying 2 Group 4.CSV',delimiter=';')
w_hk217qsuperpole = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Hong Kong2/Q/26_Weather_Super Pole 2.CSV',delimiter=';')
w_hk217rrace = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Hong Kong2/Race/26_Weather_Race 2.CSV',delimiter=';')

# %%
#COPY THIS CELL
def clean(df1, df2):
  df1[' HOUR'] = pd.to_datetime(df1[' HOUR'])
  df1['DT Elapsed'] = (df1.iloc[0:, 14] - df1.iat[1, 14])
  df1.drop(df1.index[[0,1]])
  df1['DT Elapsed'] = df1['DT Elapsed'].apply(lambda x: abs(x) if pd.notna(x) else None)
  df1.columns = df1.columns.str.replace(' ', '') 

  df2['TIME_UTC_STR'] = pd.to_datetime(df2['TIME_UTC_STR'])
  df2['Elapsed'] = df2.iloc[1:, 1] - df2.iat[0, 1]
  df2['AIR_TEMP'] = df2['AIR_TEMP'].astype(str)
  df2['TRACK_TEMP'] = df2['TRACK_TEMP'].astype(str)
  df2['WIND_SPEED'] = df2['WIND_SPEED'].astype(str)
  df2['AIR_TEMP'] = df2['AIR_TEMP'].str.replace(r'\D','.')
  df2['TRACK_TEMP'] = df2['TRACK_TEMP'].str.replace(r'\D','.')
  df2['WIND_SPEED'] = df2['WIND_SPEED'].str.replace(r'\D','.')

  df2['AIR_TEMP'] = df2['AIR_TEMP'].astype('float')
  df2['TRACK_TEMP'] = df2['TRACK_TEMP'].astype('float')
  df2['WIND_SPEED'] = df2['WIND_SPEED'].astype('float')
  return df1, df2

# %%
#COPY THIS CELL
def mergeweather(df1, df2):
  airtemplist = []
  tracktemplist = []
  windspeedlist = []
  winddirlist = []
  drivers = df1.NUMBER.unique()
  for j in range(len(drivers)):
    driverdf = df1[df1['NUMBER'] == drivers[j]].copy()
    idx = 0
    for i in range(len(driverdf)):
      check = driverdf.iloc[i,-1]
      selection = df2[(df2.iloc[0:, -1] - df2.iat[1, -1]) <= check].copy()
      idxlist = selection.index.tolist()
      selection = selection.iloc[idx-1:]
      avg = selection.mean()
      airtemp = avg['AIR_TEMP']
      tracktemp = avg['TRACK_TEMP']
      windspeed = avg['WIND_SPEED']
      winddir = avg['WIND_DIRECTION']
      airtemplist.append(airtemp)
      tracktemplist.append(tracktemp)
      windspeedlist.append(windspeed)
      winddirlist.append(winddir)
      idx = int(idxlist[-1])


  weatherdict = {'AIR_TEMP':airtemplist,'TRACK_TEMP':tracktemplist,'WIND_SPEED':windspeedlist,'WIND_DIRECTION':winddirlist}
  weatherdf = pd.DataFrame(weatherdict)
  merge = pd.concat([df1,weatherdf],axis=1,ignore_index=False,join='outer')
  df1 = merge.copy()
  return df1

# %%
#COPY THIS CELL
def dropcol(df):
  df.drop(labels=['DRIVER_NUMBER', 'CROSSING_FINISH_LINE_IN_PIT','S1','S1_IMPROVEMENT','S2','S2_IMPROVEMENT','S3','S3_IMPROVEMENT','S1_LARGE','S2_LARGE','S3_LARGE','TOP_SPEED', 'DTElapsed','Unnamed:25'], axis=1, inplace=True)
  return df

# %%
#Create Lists of Each Race

#HK 16 Q
HK16QG1_List = [hk16qg1,w_hk16qg1]

#HK 16 Race
HK16RRACE_List = [hk16ranalysis, w_hk16rrace]

#HK 17 Q
HK17QG1_List = [hk17qg1,w_hk17qg1]
HK17QG2_List = [hk17qg2,w_hk17qg2]
HK17QG3_List = [hk17qg3,w_hk17qg3]
HK17QG4_List = [hk17qg4,w_hk17qg4]
HK17QSuperPole_List = [hk17qsuperpole,w_hk17qsuperpole]

#HK 17 Race
HK17RRACE_List = [hk17ranalysis, w_hk17rrace]

#HK2 17 Q
HK217QG1_List = [hk217qg1,w_hk217qg1]
HK217QG2_List = [hk217qg2,w_hk217qg2]
HK217QG3_List = [hk217qg3,w_hk217qg3]
HK217QG4_List = [hk217qg4,w_hk217qg4]
HK217QSuperPole_List = [hk217qsuperpole,w_hk217qsuperpole]

#HK2 17 Race
HK217RRACE_List = [hk217ranalysis, w_hk217rrace]

# %%
#Create nested list

HKall_files = [HK16QG1_List,
             HK16RRACE_List,
             HK17QG1_List,
             HK17QG2_List,
             HK17QG3_List,
             HK17QG4_List,
             HK17QSuperPole_List,
             HK17RRACE_List,
             HK217QG1_List,
             HK217QG2_List,
             HK217QG3_List,
             HK217QG4_List,
             HK217QSuperPole_List,
             HK217RRACE_List,]

# %%
#COPY THIS CELL
for l in HKall_files:
  clean(l[0],l[1])
  l[0] = mergeweather(l[0],l[1])
  l[0] = dropcol(l[0])
  l = [l[0],l[1]]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# ...

# %%
HK16Q_List = [HKall_files[0][0]]

# %%
HK16R_List = [HKall_files[1][0]]

# %%
HK17Q_List = [HKall_files[2][0],
              HKall_files[3][0],
              HKall_files[4][0],
              HKall_files[5][0],
              HKall_files[8][0],
              HKall_files[9][0],
              HKall_files[10][0],
              HKall_files[11][0]]

# %%
HK17SP_List = [HKall_files[6][0],
               HKall_files[12][0]]

# %%
HK17R_List = [HKall_files[7][0],
              HKall_files[13][0]]

# %%
HK16Q = pd.concat(HK16Q_List,ignore_index=True)
HK16R = pd.concat(HK16R_List,ignore_index=True)
HK17Q = pd.concat(HK17Q_List,ignore_index=True)
HK17SP = pd.concat(HK17SP_List,ignore_index=True)
HK17R = pd.concat(HK17R_List,ignore_index=True)

# %%
HK16Q.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/HK16Q.csv")
HK16R.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/HK16R.csv")
HK17Q.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/HK17Q.csv")
HK17SP.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/HK17SP.csv")
HK17R.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/HK17R.csv")
