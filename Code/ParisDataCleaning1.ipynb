# %%
import pandas as pd
import numpy as np
import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Paris 2016-2017
pr16fp1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Paris/FP1/23_Analysis_Non Qualifying Practice 1.CSV',delimiter=';')
pr16fp2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Paris/FP2/23_Analysis_Non Qualifying Practice 2.CSV',delimiter=';')
pr16qg1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Paris/Q/Analysis_Qualifying Group 1.CSV',delimiter=';')
pr16qg2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Paris/Q/Analysis_Qualifying Group 2.CSV',delimiter=';')
pr16qg3 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Paris/Q/Analysis_Qualifying Group 3.CSV',delimiter=';')
pr16qg4 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Paris/Q/Analysis_Qualifying Group 4.CSV',delimiter=';')
pr16qsuperpole = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Paris/Q/Analysis_Superpole.CSV',delimiter=';')
pr16rclassrace = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Paris/Race/03_Classification_Race (28).CSV',delimiter=';')
pr16ranalysis = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Paris/Race/23_Analysis_Race (27).CSV',delimiter=';')

#Weather Paris 2016-2017
w_pr16fp1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Paris/FP1/26_Weather_Non Qualifying Practice 1.CSV',delimiter=';')
w_pr16fp2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Paris/FP2/26_Weather_Non Qualifying Practice 2.CSV',delimiter=';')
w_pr16qg1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Paris/Q/26_Weather_Qualifying Group 1.CSV',delimiter=';')
w_pr16qg2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Paris/Q/26_Weather_Qualifying Group 2.CSV',delimiter=';')
w_pr16qg3 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Paris/Q/26_Weather_Qualifying Group 3.CSV',delimiter=';')
w_pr16qg4 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Paris/Q/26_Weather_Qualifying Group 4.CSV',delimiter=';')
w_pr16qsuperpole = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Paris/Q/26_Weather_Superpole.CSV',delimiter=';')
w_pr16rrace = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Paris/Race/26_Weather_Race.CSV',delimiter=';')

# %%
#Paris 2017-2018
pr17fp1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Paris/FP1/23_Analysis_Non Qualifying Practice 1_.CSV',delimiter=';')
pr17fp2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Paris/FP2/23_Analysis_Non Qualifying Practice 2_.CSV',delimiter=';')
pr17qg1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Paris/Q/23_Analysis_Qualifying Group 1_.CSV',delimiter=';')
pr17qg2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Paris/Q/23_Analysis_Qualifying Group 2_.CSV',delimiter=';')
pr17qg3 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Paris/Q/23_Analysis_Qualifying Group 3_.CSV',delimiter=';')
pr17qg4 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Paris/Q/23_Analysis_Qualifying Group 4_.CSV',delimiter=';')
pr17qsuperpole = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Paris/Q/23_Analysis_Super Pole_.CSV',delimiter=';')
pr17rclassrace= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Paris/Race/1718_PR_Classification_Race.CSV',delimiter=';')
pr17ranalysis  = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Paris/Race/1718_PR_Analysis_Race.CSV',delimiter=';')

#Weather Paris 2017-2018
w_pr17fp1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Paris/FP1/26_Weather_Non Qualifying Practice 1_.CSV',delimiter=';')
w_pr17fp2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Paris/FP2/26_Weather_Non Qualifying Practice 2_.CSV',delimiter=';')
w_pr17qg1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Paris/Q/26_Weather_Qualifying Group 1_.CSV',delimiter=';')
w_pr17qg2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Paris/Q/26_Weather_Qualifying Group 2_.CSV',delimiter=';')
w_pr17qg3 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Paris/Q/26_Weather_Qualifying Group 3_.CSV',delimiter=';')
w_pr17qg4 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Paris/Q/26_Weather_Qualifying Group 4_.CSV',delimiter=';')
w_pr17qsuperpole = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Paris/Q/26_Weather_Super Pole_.CSV',delimiter=';')
w_pr17rrace = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Paris/Race/26_Weather_Race_.CSV',delimiter=';')

# %%
pr16ranalysis.columns
# Out:
# Index(['NUMBER', ' DRIVER_NUMBER', ' LAP_NUMBER', ' LAP_TIME',
#        ' LAP_IMPROVEMENT', ' CROSSING_FINISH_LINE_IN_PIT', ' S1',
#        ' S1_IMPROVEMENT', ' S2', ' S2_IMPROVEMENT', ' S3', ' S3_IMPROVEMENT',
#        ' KPH', ' ELAPSED', ' HOUR', 'S1_LARGE', 'S2_LARGE', 'S3_LARGE',
#        'TOP_SPEED', 'DRIVER_NAME', 'PIT_TIME', 'CLASS', 'GROUP', 'TEAM',
#        'MANUFACTURER', 'Unnamed: 25'],
#       dtype='object')

# %%
def add_year_type(df, Year, Type):
  df['Year'] = Year
  df['Type'] = Type
  #return df.head()

# %%
#Add year and type for 2016-2017 data
add_year_type(pr16fp1, '2016-2017','FP1')
add_year_type(pr16fp2, '2016-2017','FP2')
add_year_type(pr16qg1, '2016-2017','QF1')
add_year_type(pr16qg2, '2016-2017','QF2')
add_year_type(pr16qg3, '2016-2017','QF3')
add_year_type(pr16qg4, '2016-2017','QF4')
add_year_type(pr16qsuperpole , '2016-2017','SuperPole')
add_year_type(pr16rclassrace, '2016-2017','Classification Race')
add_year_type(pr16ranalysis, '2016-2017','Analysis Race')

#Add year and type for 2017-2018 data
add_year_type(pr17fp1, '2017-2018','FP1')
add_year_type(pr17fp2, '2017-2018','FP2')
add_year_type(pr17qg1, '2017-2018','QF1')
add_year_type(pr17qg2, '2017-2018','QF2')
add_year_type(pr17qg3, '2017-2018','QF3')
add_year_type(pr17qg4, '2017-2018','QF4')
add_year_type(pr17qsuperpole , '2017-2018','SuperPole')
add_year_type(pr17rclassrace, '2017-2018','Classification Race')
add_year_type(pr17ranalysis, '2017-2018','Analysis Race')

# %%
# Add year and type to weather data
add_year_type(w_pr16fp1, '2016-2017','FP1')
add_year_type(w_pr16fp2, '2016-2017','FP2')
add_year_type(w_pr16qg1, '2016-2017','QF1')
add_year_type(w_pr16qg2, '2016-2017','QF2')
add_year_type(w_pr16qg3, '2016-2017','QF3')
add_year_type(w_pr16qg4, '2016-2017','QF4')
add_year_type(w_pr16qsuperpole, '2016-2017','SuperPole')
add_year_type(w_pr16rrace, '2016-2017','Analysis Race')

add_year_type(w_pr17fp1, '2017-2018','FP1')
add_year_type(w_pr17fp2, '2017-2018','FP2')
add_year_type(w_pr17qg1, '2017-2018','QF1')
add_year_type(w_pr17qg2, '2017-2018','QF2')
add_year_type(w_pr17qg3, '2017-2018','QF3')
add_year_type(w_pr17qg4, '2017-2018','QF4')
add_year_type(w_pr17qsuperpole, '2017-2018','SuperPole')
add_year_type(w_pr17rrace, '2017-2018','Analysis Race')

# %%
# Consolidate the speed and lap files
df_lap_1617 = pd.concat([pr16fp1,pr16fp2,pr16qg1,pr16qg2,pr16qg3,pr16qg4,pr16qsuperpole,pr16ranalysis])
df_lap_1718 = pd.concat([pr17fp1,pr17fp2,pr17qg1,pr17qg2,pr17qg3,pr17qg4,pr17qsuperpole,pr17ranalysis])
df_lap_1618 = pd.concat([df_lap_1617,df_lap_1718 ])

df_race_class = pd.concat([pr16rclassrace,pr17rclassrace])

df_weather_1617 = pd.concat([w_pr16fp1,w_pr16fp2,w_pr16qg1,w_pr16qg2,w_pr16qg3,w_pr16qg4,w_pr16qsuperpole,w_pr16rrace])
df_weather_1718 = pd.concat([w_pr17fp1,w_pr17fp2,w_pr17qg1,w_pr17qg2,w_pr17qg3,w_pr17qg4,w_pr17qsuperpole,w_pr17rrace])

df_weather_1618 = pd.concat([df_weather_1617,df_weather_1718])

print(df_lap_1618.shape)
print(df_race_class.shape)
print(df_weather_1618.shape)
# Out:
# (3657, 28)
# (40, 42)
# (296, 11)

# %%
w_pr16fp1['TIME_UTC_STR'] = pd.to_datetime(w_pr16fp1['TIME_UTC_STR'])
w_pr16fp1['Seconds'] = w_pr16fp1['TIME_UTC_STR'].dt.second
w_pr16fp1['Elapsed'] = w_pr16fp1['Seconds'].cumsum()



w_pr16fp1.head(20)
# Out:
#     TIME_UTC_SECONDS        TIME_UTC_STR AIR_TEMP  ... Unnamed: 8  Seconds Elapsed
# 0         1495260054 2017-05-20 06:00:54  9,61111  ...        NaN       54      54
# 1         1495260119 2017-05-20 06:01:59  9,66667  ...        NaN       59     113
# 2         1495260185 2017-05-20 06:03:05  9,66667  ...        NaN        5     118
# 3         1495260250 2017-05-20 06:04:10  9,72222  ...        NaN       10     128
# 4         1495260315 2017-05-20 06:05:15  9,72222  ...        NaN       15     143
# 5         1495260380 2017-05-20 06:06:20  9,77778  ...        NaN       20     163
# 6         1495260445 2017-05-20 06:07:25  9,77778  ...        NaN       25     188
# 7         1495260510 2017-05-20 06:08:30  9,77778  ...        NaN       30     218
# 8         1495260575 2017-05-20 06:09:35  9,83333  ...        NaN       35     253
# 9         1495260640 2017-05-20 06:10:40  9,83333  ...        NaN       40     293
# ...

# %%
#COPY THIS CELL
def clean(df1, df2):
  df1[' HOUR'] = pd.to_datetime(df1[' HOUR'])
  df1['DT Elapsed'] = (df1.iloc[0:, 14] - df1.iat[1, 14])
  df1.drop(df1.index[[0,1]])
  df1['DT Elapsed'] = df1['DT Elapsed'].apply(lambda x: abs(x) if pd.notna(x) else None)
  df1.columns = df1.columns.str.replace(' ', '') 

  df2['TIME_UTC_STR'] = pd.to_datetime(df2['TIME_UTC_STR'])
  df2['Elapsed'] = df2.iloc[1:, 1] - df2.iat[0, 1]
  df2['AIR_TEMP'] = df2['AIR_TEMP'].astype(str)
  df2['TRACK_TEMP'] = df2['TRACK_TEMP'].astype(str)
  df2['WIND_SPEED'] = df2['WIND_SPEED'].astype(str)
  df2['AIR_TEMP'] = df2['AIR_TEMP'].str.replace(r'\D','.')
  df2['TRACK_TEMP'] = df2['TRACK_TEMP'].str.replace(r'\D','.')
  df2['WIND_SPEED'] = df2['WIND_SPEED'].str.replace(r'\D','.')

  df2['AIR_TEMP'] = df2['AIR_TEMP'].astype('float')
  df2['TRACK_TEMP'] = df2['TRACK_TEMP'].astype('float')
  df2['WIND_SPEED'] = df2['WIND_SPEED'].astype('float')
  return df1, df2

# %%
#COPY THIS CELL
def mergeweather(df1, df2):
  airtemplist = []
  tracktemplist = []
  windspeedlist = []
  winddirlist = []
  drivers = df1.NUMBER.unique()
  for j in range(len(drivers)):
    driverdf = df1[df1['NUMBER'] == drivers[j]].copy()
    idx = 0
    for i in range(len(driverdf)):
      check = driverdf.iloc[i,-1]
      selection = df2[(df2.iloc[0:, -1] - df2.iat[1, -1]) <= check].copy()
      idxlist = selection.index.tolist()
      selection = selection.iloc[idx-1:]
      avg = selection.mean()
      airtemp = avg['AIR_TEMP']
      tracktemp = avg['TRACK_TEMP']
      windspeed = avg['WIND_SPEED']
      winddir = avg['WIND_DIRECTION']
      airtemplist.append(airtemp)
      tracktemplist.append(tracktemp)
      windspeedlist.append(windspeed)
      winddirlist.append(winddir)
      idx = int(idxlist[-1])


  weatherdict = {'AIR_TEMP':airtemplist,'TRACK_TEMP':tracktemplist,'WIND_SPEED':windspeedlist,'WIND_DIRECTION':winddirlist}
  weatherdf = pd.DataFrame(weatherdict)
  merge = pd.concat([df1,weatherdf],axis=1,ignore_index=False,join='outer')
  df1 = merge.copy()
  return df1

# %%
#COPY THIS CELL
def dropcol(df):
  df.drop(labels=['DRIVER_NUMBER', 'CROSSING_FINISH_LINE_IN_PIT','S1','S1_IMPROVEMENT','S2','S2_IMPROVEMENT','S3','S3_IMPROVEMENT','S1_LARGE','S2_LARGE','S3_LARGE','TOP_SPEED', 'DTElapsed','Unnamed:25'], axis=1, inplace=True)
  return df

# %%
#Create Lists of Each Race
#PR 16 Q
PR16QG1_List = [pr16qg1,w_pr16qg1]
PR16QG2_List = [pr16qg2,w_pr16qg2]
PR16QG3_List = [pr16qg3,w_pr16qg3]
PR16QG4_List = [pr16qg4,w_pr16qg4]
PR16QSuperPole_List = [pr16qsuperpole,w_pr16qsuperpole]

#PR 16 Race
PR16Race_List = [pr16ranalysis,w_pr16rrace]
#NY 17 Q
PR17QG1_List = [pr17qg1,w_pr17qg1]
PR17QG2_List = [pr17qg2,w_pr17qg2]
PR17QG3_List = [pr17qg3,w_pr17qg3]
PR17QG4_List = [pr17qg4,w_pr17qg4]
PR17QSuperPole_List = [pr17qsuperpole,w_pr17qsuperpole]

#PR 17 Race
PR17Race_List = [pr17ranalysis,w_pr17rrace]

# %%
#Create nested list
all_files = [PR16QG1_List,
             PR16QG2_List,
             PR16QG3_List,
             PR16QG4_List,
             PR16QSuperPole_List,
             PR16Race_List,
             PR17QG1_List,
             PR17QG2_List,
             PR17QG3_List,
             PR17QG4_List,
             PR17QSuperPole_List,
             PR17Race_List]

# %%
#COPY THIS CELL
for l in all_files:
  clean(l[0],l[1])
  l[0] = mergeweather(l[0],l[1])
  l[0] = dropcol(l[0])
  l = [l[0],l[1]]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# ...

# %%
all_files[-1][0].head()
# Out:
#    NUMBER  LAP_NUMBER  LAP_TIME  ...  TRACK_TEMP  WIND_SPEED WIND_DIRECTION
# 0       1           0  1:00.701  ...     22.7778    1.060930          142.0
# 1       1           1  2:07.780  ...         NaN         NaN            NaN
# 2       1           2  1:04.960  ...     22.7778    3.182805          135.0
# 3       1           3  1:04.103  ...     22.7778    1.591400          132.0
# 4       1           4  1:04.029  ...     22.7778    1.060930          179.0
#
# [5 rows x 17 columns]

# %%
PR16Q_List = [all_files[0][0],
              all_files[1][0],
              all_files[2][0],
              all_files[3][0]]

# %%
PR16SP_List = [all_files[4][0]]

# %%
PR16R_List = [all_files[5][0]]

# %%
PR17Q_List = [all_files[6][0],
              all_files[7][0],
              all_files[8][0],
              all_files[9][0]]

# %%
PR17SP_List = [all_files[10][0]]

# %%
PR17R_List = [all_files[11][0]]

# %%
PR16Q = pd.concat(PR16Q_List,ignore_index=True)
PR16SP = pd.concat(PR16SP_List,ignore_index=True)
PR16R = pd.concat(PR16R_List,ignore_index=True)
PR17Q = pd.concat(PR17Q_List,ignore_index=True)
PR17SP = pd.concat(PR17SP_List,ignore_index=True)
PR17R = pd.concat(PR17R_List,ignore_index=True)

# %%
PR16Q.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/PR16Q.csv")
PR16SP.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/PR16SP.csv")
PR16R.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/PR16R.csv")
PR17Q.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/PR17Q.csv")
PR17SP.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/PR17SP.csv")
PR17R.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/PR17R.csv")
