# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
#Berlin16-17
ber16fp1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Berlin/FP1/23_Analysis_Non Qualifying Practice 1.CSV', delimiter=';')
ber16fp2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Berlin/FP2/23_Analysis_Non Qualifying Practice 2.CSV', delimiter=';')
ber16qg1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Berlin/Q/23_Analysis_Qualifying 1 Group 1.CSV', delimiter=';')
ber16qg2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Berlin/Q/23_Analysis_Qualifying 1 Group 2.CSV', delimiter=';')
ber16qg3 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Berlin/Q/23_Analysis_Qualifying 1 Group 3.CSV', delimiter=';')
ber16qg4 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Berlin/Q/23_Analysis_Qualifying 1 Group 4.CSV', delimiter=';')
ber16qsp = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Berlin/Q/23_Analysis_Super Pole 1.CSV', delimiter=';')
ber16c_race = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Berlin/Race/03_Classification_Race 1.CSV', delimiter=';')
ber16a_race = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Berlin/Race/23_Analysis_Race 1.CSV', delimiter=';')

w16fp1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Berlin/FP1/26_Weather_Non Qualifying Practice 1.CSV',delimiter=';')
w16fp2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Berlin/FP2/26_Weather_Non Qualifying Practice 2.CSV',delimiter=';')
w16qg1= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Berlin/Q/26_Weather_Qualifying 1 Group 1.CSV', delimiter=';')
w16qg2= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Berlin/Q/26_Weather_Qualifying 1 Group 2.CSV', delimiter=';')
w16qg3= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Berlin/Q/26_Weather_Qualifying 1 Group 3.CSV', delimiter=';')
w16qg4= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Berlin/Q/26_Weather_Qualifying 1 Group 4.CSV', delimiter=';')
w16qsp= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Berlin/Q/26_Weather_Super Pole 1.CSV', delimiter=';')
w16race = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Berlin/Race/26_Weather_Race 1.CSV', delimiter=';')

# %%
#Berlin216-17
ber216fp1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Berlin2/FP1/23_Analysis_Non Qualifying Practice 3.CSV',delimiter=';')
ber216fp2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Berlin2/FP2/23_Analysis_Non Qualifying Practice 4.CSV',delimiter=';')
ber216qg1= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Berlin2/Q/23_Analysis_Qualifying 2 Group 1.CSV', delimiter=';')
ber216qg2= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Berlin2/Q/23_Analysis_Qualifying 2 Group 2.CSV', delimiter=';')
ber216qg3= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Berlin2/Q/23_Analysis_Qualifying 2 Group 3.CSV', delimiter=';')
ber216qg4= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Berlin2/Q/23_Analysis_Qualifying 2 Group 4.CSV', delimiter=';')
ber216qsp= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Berlin2/Q/23_Analysis_Super Pole 2.CSV', delimiter=';')
ber216c_race = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Berlin2/Race/03_Classification_Race 2.CSV', delimiter=';')
ber216a_race = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Berlin2/Race/23_Analysis_Race 2.CSV', delimiter=';')

w216fp1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Berlin2/FP1/26_Weather_Non Qualifying Practice 3.CSV',delimiter=';')
w216fp2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Berlin2/FP2/26_Weather_Non Qualifying Practice 4.CSV',delimiter=';')
w216qg1= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Berlin2/Q/26_Weather_Qualifying 2 Group 1.CSV', delimiter=';')
w216qg2= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Berlin2/Q/26_Weather_Qualifying 2 Group 2.CSV', delimiter=';')
w216qg3= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Berlin2/Q/26_Weather_Qualifying 2 Group 3.CSV', delimiter=';')
w216qg4= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Berlin2/Q/26_Weather_Qualifying 2 Group 4.CSV', delimiter=';')
w216qsp= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Berlin2/Q/26_Weather_Super Pole 2.CSV', delimiter=';')
w216race = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Berlin2/Race/26_Weather_Race 2.CSV', delimiter=';')

# %%
#Berlin17-18
ber17fp1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Berlin/FP1/23_Analysis_Non Qualifying Practice 1.CSV',delimiter=';')
ber17fp2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Berlin/FP2/23_Analysis_Non Qualifying Practice 2.CSV',delimiter=';')
ber17qg1= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Berlin/Q/23_Analysis_Qualifying Group 1.CSV', delimiter=';')
ber17qg2= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Berlin/Q/23_Analysis_Qualifying Group 2.CSV', delimiter=';')
ber17qg3= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Berlin/Q/23_Analysis_Qualifying Group 3.CSV', delimiter=';')
ber17qg4= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Berlin/Q/23_Analysis_Qualifying Group 4.CSV', delimiter=';')
ber17qsp= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Berlin/Q/23_Analysis_Super Pole.CSV', delimiter=';')
ber17c_race = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Berlin/Race/03_Classification_Race (33).CSV', delimiter=';')
ber17a_race = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Berlin/Race/23_Analysis_Race (32).CSV', delimiter=';')


w17fp1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Berlin/FP1/26_Weather_Non Qualifying Practice 1.CSV',delimiter=';')
w17fp2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Berlin/FP2/26_Weather_Non Qualifying Practice 2.CSV',delimiter=';')
w17qg1= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Berlin/Q/26_Weather_Qualifying Group 1.CSV', delimiter=';')
w17qg2= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Berlin/Q/26_Weather_Qualifying Group 2.CSV', delimiter=';')
w17qg3= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Berlin/Q/26_Weather_Qualifying Group 3.CSV', delimiter=';')
w17qg4= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Berlin/Q/26_Weather_Qualifying Group 4.CSV', delimiter=';')
w17qsp= pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Berlin/Q/26_Weather_Super Pole.CSV', delimiter=';')
w17race = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Berlin/Race/26_Weather_Race.CSV', delimiter=';')

# %%
def dropcol(df):
  df.drop(labels=[' DRIVER_NUMBER', ' CROSSING_FINISH_LINE_IN_PIT','TOP_SPEED', 'Unnamed: 25'], axis=1, inplace=True)

# %%
def wdropcol(df):
  df.drop('Unnamed: 8', axis=1, inplace=True)

# %%
dropcol(ber16fp1)
dropcol(ber16fp2)
dropcol(ber16qg1)
dropcol(ber16qg2)
dropcol(ber16qg3)
dropcol(ber16qg4)
dropcol(ber16qsp)
dropcol(ber16a_race)

# %%
dropcol(ber216fp1)
dropcol(ber216fp2)
dropcol(ber216qg1)
dropcol(ber216qg2)
dropcol(ber216qg3)
dropcol(ber216qg4)
dropcol(ber216qsp)
dropcol(ber216a_race)

# %%
dropcol(ber17fp1)
dropcol(ber17fp2)
dropcol(ber17qg1)
dropcol(ber17qg2)
dropcol(ber17qg3)
dropcol(ber17qg4)
dropcol(ber17qsp)
dropcol(ber17a_race)

# %%
wdropcol(w16fp1)
wdropcol(w16fp2)
wdropcol(w16qg1)
wdropcol(w16qg2)
wdropcol(w16qg3)
wdropcol(w16qg4)
wdropcol(w16qsp)
wdropcol(w16race)

# %%
wdropcol(w216fp1)
wdropcol(w216fp2)
wdropcol(w216qg1)
wdropcol(w216qg2)
wdropcol(w216qg3)
wdropcol(w216qg4)
wdropcol(w216qsp)
wdropcol(w216race)

# %%
wdropcol(w17fp1)
wdropcol(w17fp2)
wdropcol(w17qg1)
wdropcol(w17qg2)
wdropcol(w17qg3)
wdropcol(w17qg4)
wdropcol(w17qsp)
wdropcol(w17race)

# %%
def todt(w16fp1):
  w16fp1['TIME_UTC_STR'] = pd.to_datetime(w16fp1['TIME_UTC_STR'])
  w16fp1['Seconds'] = w16fp1['TIME_UTC_STR'].dt.second
  w16fp1['Elapsed'] = w16fp1['Seconds'].cumsum()
  return w16fp1.head(20)

# %%
todt(w16fp1)
todt(w16fp2)
todt(w16qg1)
todt(w16qg2)
todt(w16qg3)
todt(w16qg4)
todt(w16qsp)
todt(w16race)

# %%
#COPY THIS CELL
def clean(df1, df2):
  df1[' HOUR'] = pd.to_datetime(df1[' HOUR'])
  df1['DT Elapsed'] = (df1.iloc[0:, 14] - df1.iat[1, 14])
  df1.drop(df1.index[[0,1]])
  df1['DT Elapsed'] = df1['DT Elapsed'].apply(lambda x: abs(x) if pd.notna(x) else None)
  df1.columns = df1.columns.str.replace(' ', '') 

  df2['TIME_UTC_STR'] = pd.to_datetime(df2['TIME_UTC_STR'])
  df2['Elapsed'] = df2.iloc[1:, 1] - df2.iat[0, 1]
  df2['AIR_TEMP'] = df2['AIR_TEMP'].astype(str)
  df2['TRACK_TEMP'] = df2['TRACK_TEMP'].astype(str)
  df2['WIND_SPEED'] = df2['WIND_SPEED'].astype(str)
  df2['AIR_TEMP'] = df2['AIR_TEMP'].str.replace(r'\D','.')
  df2['TRACK_TEMP'] = df2['TRACK_TEMP'].str.replace(r'\D','.')
  df2['WIND_SPEED'] = df2['WIND_SPEED'].str.replace(r'\D','.')

  df2['AIR_TEMP'] = df2['AIR_TEMP'].astype('float')
  df2['TRACK_TEMP'] = df2['TRACK_TEMP'].astype('float')
  df2['WIND_SPEED'] = df2['WIND_SPEED'].astype('float')
  return df1, df2

# %%
#COPY THIS CELL
def mergeweather(df1, df2):
  airtemplist = []
  tracktemplist = []
  windspeedlist = []
  winddirlist = []
  drivers = df1.NUMBER.unique()
  for j in range(len(drivers)):
    driverdf = df1[df1['NUMBER'] == drivers[j]].copy()
    idx = 0
    for i in range(len(driverdf)):
      check = driverdf.iloc[i,-1]
      selection = df2[(df2.iloc[0:, -1] - df2.iat[1, -1]) <= check].copy()
      idxlist = selection.index.tolist()
      selection = selection.iloc[idx-1:]
      avg = selection.mean()
      airtemp = avg['AIR_TEMP']
      tracktemp = avg['TRACK_TEMP']
      windspeed = avg['WIND_SPEED']
      winddir = avg['WIND_DIRECTION']
      airtemplist.append(airtemp)
      tracktemplist.append(tracktemp)
      windspeedlist.append(windspeed)
      winddirlist.append(winddir)
      idx = int(idxlist[-1])


  weatherdict = {'AIR_TEMP':airtemplist,'TRACK_TEMP':tracktemplist,'WIND_SPEED':windspeedlist,'WIND_DIRECTION':winddirlist}
  weatherdf = pd.DataFrame(weatherdict)
  merge = pd.concat([df1,weatherdf],axis=1,ignore_index=False,join='outer')
  df1 = merge.copy()
  return df1

# %%
#COPY THIS CELL
def dropcol(df):
  df.drop(labels=['DRIVER_NUMBER', 'CROSSING_FINISH_LINE_IN_PIT','S1','S1_IMPROVEMENT','S2','S2_IMPROVEMENT','S3','S3_IMPROVEMENT','S1_LARGE','S2_LARGE','S3_LARGE','TOP_SPEED', 'DTElapsed','Unnamed:25'], axis=1, inplace=True)
  return df

# %%
#Create Lists of Each Race


#Berlin 16 Q
B16QG1_List = [ber16qg1,w16qg1]
B16QG2_List = [ber16qg2,w16qg2]
B16QG3_List = [ber16qg3,w16qg3]
B16QG4_List = [ber16qg4,w16qg4]
B16QSuperPole_List = [ber16qsp,w16qsp]

#Berlin 16 Race
B16A_List = [ber16a_race, w16race]

#Berlin 2 16 Q
B216QG1_List = [ber216qg1,w216qg1]
B216QG2_List = [ber216qg2,w216qg2]
B216QG3_List = [ber216qg3,w216qg3]
B216QG4_List = [ber216qg4,w216qg4]
B216QSuperPole_List = [ber216qsp,w216qsp]

#Berlin 2 16 Race
B216A_List = [ber216a_race, w216race]

#Berlin 17 Q
B17QG1_List = [ber17qg1,w17qg1]
B17QG2_List = [ber17qg2,w17qg2]
B17QG3_List = [ber17qg3,w17qg3]
B17QG4_List = [ber17qg4,w17qg4]
B17QSuperPole_List = [ber17qsp,w17qsp]

#Berlin 17 Race
B17A_List = [ber17a_race, w17race]

#16-17
#BQ16_List = [B16QG1_List, B16QG2_List, B16QG3_List, B16QG4_List, B216QG1_List, B216QG2_List, B216QG3_List, B216QG4_List]
#BQSP16_List = [B16QSuperPole_Lis, B216QSuperPole_List]
#BARace16_List = [B16A_List, B216A_List]

#17-18
#BQ17_List = [B17QG1_List, B17QG2_List, B17QG3_List, B17QG4_List]
#BQSP17_List = [B17QSuperPole_List]
#BARace17_List = [B17A_List]

# %%
#Create nested list

all_files = [B16QG1_List,
             B16QG2_List,
             B16QG3_List,
             B16QG4_List,
             B16QSuperPole_List,
             B16A_List,
             B216QG1_List,
             B216QG2_List,
             B216QG3_List,
             B216QG4_List,
             B216QSuperPole_List,
             B216A_List,
             B17QG1_List,
             B17QG2_List,
             B17QG3_List,
             B17QG4_List,
             B17QSuperPole_List,
             B17A_List]

# %%
#COPY THIS CELL
for l in all_files:
  clean(l[0],l[1])
  l[0] = mergeweather(l[0],l[1])
  l[0] = dropcol(l[0])
  l = [l[0],l[1]]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# ...

# %%
B16Q_List = [all_files[0][0],
              all_files[1][0],
              all_files[2][0],
              all_files[3][0],
              all_files[6][0],
              all_files[7][0],
              all_files[8][0],
              all_files[9][0]]

# %%
B16SP_List = [all_files[4][0],
              all_files[10][0]]

# %%
B16R_List = [all_files[5][0],
              all_files[11][0]]

# %%
B17Q_List = [all_files[12][0],
             all_files[13][0],
             all_files[14][0],
             all_files[15][0]]

# %%
B17SP_List = [all_files[16][0]]

# %%
B17R_List = [all_files[17][0]]

# %%
B16Q = pd.concat(B16Q_List,ignore_index=True)
B16SP = pd.concat(B16SP_List,ignore_index=True)
B16R = pd.concat(B16R_List,ignore_index=True)
B17Q = pd.concat(B17Q_List,ignore_index=True)
B17SP = pd.concat(B17SP_List,ignore_index=True)
B17R = pd.concat(B17R_List,ignore_index=True)

# %%
B16Q.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/B16Q.csv")
B16SP.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/B16SP.csv")
B16R.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/B16R.csv")
B17Q.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/B17Q.csv")
B17SP.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/B17SP.csv")
B17R.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/B17R.csv")

# %% [markdown]
# ['NUMBER', ' DRIVER_NUMBER', ' LAP_NUMBER', ' LAP_TIME', ' LAP_IMPROVEMENT', ' CROSSING_FINISH_LINE_IN_PIT', ' S1', ' S1_IMPROVEMENT', ' S2', ' S2_IMPROVEMENT', ' S3', ' S3_IMPROVEMENT', ' KPH', ' ELAPSED', ' HOUR', 'S1_LARGE', 'S2_LARGE', 'S3_LARGE', 'TOP_SPEED', 'DRIVER_NAME', 'PIT_TIME', 'CLASS', 'GROUP', 'TEAM', 'MANUFACTURER', 'Unnamed: 25', 'DT Elapsed', 'AIR_TEMP', 'TRACK_TEMP', 'WIND_SPEED', 'WIND_DIRECTION']
#
# How do (Air temp, track temp, wind speed, wind direction, Kph, lap_time )affect number of laps left in race
