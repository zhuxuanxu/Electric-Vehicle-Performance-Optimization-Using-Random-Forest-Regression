# %%
from google.colab import files, drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

#Mexico 2016-2017

dfMC16FP1 = pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Mexico/FP1/23_Analysis_Non Qualifying Practice 1.CSV",delimiter=";")
dfMC16FP2= pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Mexico/FP2/23_Analysis_Non Qualifying Practice 2.CSV",delimiter=";")
dfMC16Q=pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Mexico/Q/23_Analysis_Groups Qualifying Session.CSV",delimiter=";")
dfMC16SuperPole=pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Mexico/Q/23_Analysis_Super Pole Session.CSV",delimiter=";")
dfMC16Class_Race=pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Mexico/Race/03_Classification_Race (26).CSV",delimiter=";")
dfMC16Analysis_Race=pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Mexico/Race/23_Analysis_Race (25).CSV",delimiter=";")


#print(df.to_string(index=False))

# %%
#Mexico 2017-2018
dfMC17FP1= pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Mexico city/FP1/23_Analysis_Non Qualifying Practice 1.CSV",delimiter=";")
dfMC17FP2= pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Mexico city/FP2/23_Analysis_Non Qualifying Practice 2.CSV",delimiter=";")
dfMC17Q_G1= pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Mexico city/Q/23_Analysis_Qualifying Group 1.CSV",delimiter=";")
dfMC17Q_G2= pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Mexico city/Q/23_Analysis_Qualifying Group 2.CSV",delimiter=";")
dfMC17Q_G3= pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Mexico city/Q/23_Analysis_Qualifying Group 3.CSV",delimiter=";")
dfMC17Q_G4= pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Mexico city/Q/23_Analysis_Qualifying Group 4.CSV",delimiter=";")
dfMC17SuperPole= pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Mexico city/Q/23_Analysis_Super Pole.CSV",delimiter=";")
dfMC17Class_Race= pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Mexico city/Race/03_Classification_Race (31).CSV",delimiter=";")
dfMC17Analysis_Race= pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Mexico city/Race/23_Analysis_Race (30).CSV",delimiter=";")

# %%
#MexicoWeather 2016-2017
w_MC16FP1 = pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Mexico/FP1/26_Weather_Non Qualifying Practice 1.CSV",delimiter=";")
w_MC16FP2 = pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Mexico/FP2/26_Weather_Non Qualifying Practice 2.CSV",delimiter=";")
w_MC16Q=pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Mexico/Q/26_Weather_Groups Qualifying Session.CSV",delimiter=";")
w_MC16SuperPole=pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Mexico/Q/26_Weather_Super Pole Session.CSV",delimiter=";")
w_MC16Race=pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Mexico/Race/26_Weather_Race.CSV",delimiter=";")

# %%
#MexicoWeather 2017-2018
w_MC17FP1 = pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Mexico city/FP1/26_Weather_Non Qualifying Practice 1.CSV",delimiter=";")
w_MC17FP2 = pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Mexico city/FP2/26_Weather_Non Qualifying Practice 2.CSV",delimiter=";")
w_MC17Q_G1=pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Mexico city/Q/26_Weather_Qualifying Group 1.CSV",delimiter=";")
w_MC17Q_G2=pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Mexico city/Q/26_Weather_Qualifying Group 2.CSV",delimiter=";")
w_MC17Q_G3=pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Mexico city/Q/26_Weather_Qualifying Group 3.CSV",delimiter=";")
w_MC17Q_G4=pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Mexico city/Q/26_Weather_Qualifying Group 4.CSV",delimiter=";")
w_MC17SuperPole=pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Mexico city/Q/26_Weather_Super Pole.CSV",delimiter=";")
w_MC17Race=pd.read_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Mexico city/Race/26_Weather_Race.CSV",delimiter=";")

# %%
#COPY THIS CELL
def clean(df1, df2):
  df1[' HOUR'] = pd.to_datetime(df1[' HOUR'])
  df1['DT Elapsed'] = (df1.iloc[0:, 14] - df1.iat[1, 14])
  df1.drop(df1.index[[0,1]])
  df1['DT Elapsed'] = df1['DT Elapsed'].apply(lambda x: abs(x) if pd.notna(x) else None)
  df1.columns = df1.columns.str.replace(' ', '') 

  df2['TIME_UTC_STR'] = pd.to_datetime(df2['TIME_UTC_STR'])
  df2['Elapsed'] = df2.iloc[1:, 1] - df2.iat[0, 1]
  df2['AIR_TEMP'] = df2['AIR_TEMP'].astype(str)
  df2['TRACK_TEMP'] = df2['TRACK_TEMP'].astype(str)
  df2['WIND_SPEED'] = df2['WIND_SPEED'].astype(str)
  df2['AIR_TEMP'] = df2['AIR_TEMP'].str.replace(r'\D','.')
  df2['TRACK_TEMP'] = df2['TRACK_TEMP'].str.replace(r'\D','.')
  df2['WIND_SPEED'] = df2['WIND_SPEED'].str.replace(r'\D','.')

  df2['AIR_TEMP'] = df2['AIR_TEMP'].astype('float')
  df2['TRACK_TEMP'] = df2['TRACK_TEMP'].astype('float')
  df2['WIND_SPEED'] = df2['WIND_SPEED'].astype('float')
  return df1, df2

# %%
#COPY THIS CELL
def mergeweather(df1, df2):
  airtemplist = []
  tracktemplist = []
  windspeedlist = []
  winddirlist = []
  drivers = df1.NUMBER.unique()
  for j in range(len(drivers)):
    driverdf = df1[df1['NUMBER'] == drivers[j]].copy()
    idx = 0
    for i in range(len(driverdf)):
      check = driverdf.iloc[i,-1]
      selection = df2[(df2.iloc[0:, -1] - df2.iat[1, -1]) <= check].copy()
      idxlist = selection.index.tolist()
      selection = selection.iloc[idx-1:]
      avg = selection.mean()
      airtemp = avg['AIR_TEMP']
      tracktemp = avg['TRACK_TEMP']
      windspeed = avg['WIND_SPEED']
      winddir = avg['WIND_DIRECTION']
      airtemplist.append(airtemp)
      tracktemplist.append(tracktemp)
      windspeedlist.append(windspeed)
      winddirlist.append(winddir)
      idx = int(idxlist[-1])


  weatherdict = {'AIR_TEMP':airtemplist,'TRACK_TEMP':tracktemplist,'WIND_SPEED':windspeedlist,'WIND_DIRECTION':winddirlist}
  weatherdf = pd.DataFrame(weatherdict)
  merge = pd.concat([df1,weatherdf],axis=1,ignore_index=False,join='outer')
  df1 = merge.copy()
  return df1

# %%
#COPY THIS CELL
def dropcol(df):
  df.drop(labels=['DRIVER_NUMBER', 'CROSSING_FINISH_LINE_IN_PIT','S1','S1_IMPROVEMENT','S2','S2_IMPROVEMENT','S3','S3_IMPROVEMENT','S1_LARGE','S2_LARGE','S3_LARGE','TOP_SPEED', 'DTElapsed','Unnamed:25'], axis=1, inplace=True)
  return df

# %%
dfMC16Q
# Out:
#     NUMBER   DRIVER_NUMBER  ...  MANUFACTURER Unnamed: 25
# 0       11               0  ...           NaN         NaN
# 1       11               0  ...           NaN         NaN
# 2       11               0  ...           NaN         NaN
# 3       11               0  ...           NaN         NaN
# 4       19               0  ...           NaN         NaN
# ..     ...             ...  ...           ...         ...
# 78      88               0  ...           NaN         NaN
# 79       9               0  ...           NaN         NaN
# 80       9               0  ...           NaN         NaN
# 81       9               0  ...           NaN         NaN
# 82       9               0  ...           NaN         NaN
#
# [83 rows x 26 columns]

# %%
#Create Lists of Each Race


#MEXICO 16 Q

dfMC16Q_List=[dfMC16Q,w_MC16Q]

#MEXICO 16 Super Pole
dfMC16SuperPole_List=[dfMC16SuperPole,w_MC16SuperPole]

#Mexico 16 Race
dfMC16Analysis_Race_List=[dfMC16Analysis_Race,w_MC16Race]


#Mexico 17 Q
dfMC17Q_G1_List=[dfMC17Q_G1,w_MC17Q_G1]
dfMC17Q_G2_List=[dfMC17Q_G2,w_MC17Q_G2]
dfMC17Q_G3_List=[dfMC17Q_G3,w_MC17Q_G3]
dfMC17Q_G4_List=[dfMC17Q_G4,w_MC17Q_G4]

#Mexico Super Pole
dfMC17SuperPole_List=[dfMC17SuperPole,w_MC17SuperPole]

#Mexico 17 Race
dfMC17Analysis_Race_List=[dfMC17Analysis_Race,w_MC17Race]

# %%
all_files=[dfMC16Q_List,
           dfMC16SuperPole_List,
           dfMC16Analysis_Race_List,
           dfMC17Q_G1_List,
           dfMC17Q_G2_List,
           dfMC17Q_G3_List,
           dfMC17Q_G4_List,
           dfMC17SuperPole_List,
           dfMC17Analysis_Race_List
          ]

# %%
#COPY THIS CELL
for l in all_files:
  clean(l[0],l[1])
  l[0] = mergeweather(l[0],l[1])
  l[0] = dropcol(l[0])
  l = [l[0],l[1]]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# ...

# %%
all_files[-1][0].head()
# Out:
#    NUMBER  LAP_NUMBER  LAP_TIME  ...  TRACK_TEMP  WIND_SPEED WIND_DIRECTION
# 0       1           1  1:15.923  ...     41.6667    2.121870     275.000000
# 1       1           2  1:04.527  ...     41.6667    2.121870     275.000000
# 2       1           3  1:04.730  ...     41.6667    2.121870     275.000000
# 3       1           4  1:04.964  ...     41.6667    1.591400     275.000000
# 4       1           5  1:04.723  ...     41.6667    1.414577     328.333333
#
# [5 rows x 17 columns]

# %%
dfMC16Q_List=[all_files[0][0]]

dfMC16SuperPole_List=[all_files[1][0]]

dfMC16Analysis_Race_List=[all_files[2][0]]

dfMC17Q_List=[all_files[3][0],
              all_files[4][0],
              all_files[5][0],
              all_files[6][0]]

dfMC17SuperPole_List=[all_files[7][0]]

dfMC17Analysis_Race_List=[all_files[8][0]]

# %%
dfMC16Q = pd.concat(dfMC16Q_List,ignore_index=True)
dfMC16SuperPole = pd.concat(dfMC16SuperPole_List,ignore_index=True)
dfMC16Analysis_Race = pd.concat(dfMC16Analysis_Race_List,ignore_index=True)
dfMC17Q = pd.concat(dfMC17Q_List,ignore_index=True)
dfMC17SuperPole = pd.concat(dfMC17SuperPole_List,ignore_index=True)
dfMC17Analysis_Race = pd.concat(dfMC17Analysis_Race_List,ignore_index=True)

# %%
dfMC16Q.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/MC16Q.csv")
dfMC16SuperPole.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/MC16SP.csv")
dfMC16Analysis_Race.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/MC16R.csv")
dfMC17Q.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/MC17Q.csv")
dfMC17SuperPole.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/MC17SP.csv")
dfMC17Analysis_Race.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/MC17R.csv")
