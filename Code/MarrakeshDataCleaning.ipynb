# %%
import pandas as pd
import numpy as np
import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Marrakesh 2016-2017
ma16qg1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Marrakesh/Q/23_Analysis_Groups Qualifying Session.CSV',delimiter=';')
ma16qsuperpole = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Marrakesh/Q/23_Analysis_Super Pole Session.CSV',delimiter=';')
ma16ranalysis = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2016-2017/Marrakesh/Race/23_Analysis_Race (23).CSV',delimiter=';')

# %%
# Marrakesh 2017-2018
ma17qg1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Marrakesh/Q/23_Analysis_Qualifying Group 1.CSV',delimiter=';')
ma17qg2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Marrakesh/Q/23_Analysis_Qualifying Group 2.CSV',delimiter=';')
ma17qg3 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Marrakesh/Q/23_Analysis_Qualifying Group 3.CSV',delimiter=';')
ma17qg4 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Marrakesh/Q/23_Analysis_Qualifying Group 4.CSV',delimiter=';')
ma17qsuperpole = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Marrakesh/Q/23_Analysis_Super Pole.CSV',delimiter=';')
ma17ranalysis = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/2017-2018/Marrakesh/Race/23_Analysis_Race (28).CSV',delimiter=';')

# %%
#Weather Marrakesh 2016-2017
w_ma16fp1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Marrakesh/FP1/26_Weather_Non Qualifying Practice 1.CSV',delimiter=';')
w_ma16fp2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Marrakesh/FP2/26_Weather_Non Qualifying Practice 2.CSV',delimiter=';')
w_ma16qg1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Marrakesh/Q/26_Weather_Groups Qualifying Session.CSV',delimiter=';')
w_ma16qsuperpole = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Marrakesh/Q/26_Weather_Super Pole Session.CSV',delimiter=';')
w_ma16race = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2016-2017/Marrakesh/Race/26_Weather_Race.CSV',delimiter=';')

# %%
#Weather Marrakesh 2017-2018
w_ma17qg1 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Marrakesh/Q/26_Weather_Qualifying Group 1.CSV',delimiter=';')
w_ma17qg2 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Marrakesh/Q/26_Weather_Qualifying Group 2.CSV',delimiter=';')
w_ma17qg3 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Marrakesh/Q/26_Weather_Qualifying Group 3.CSV',delimiter=';')
w_ma17qg4 = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Marrakesh/Q/26_Weather_Qualifying Group 4.CSV',delimiter=';')
w_ma17qsuperpole = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Marrakesh/Q/26_Weather_Super Pole.CSV',delimiter=';')
w_ma17race = pd.read_csv('/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/EVRData/Data/Req Documents New/Wheather/2016-2018/16-18/2017-2018/Marrakesh/Race/26_Weather_Race.CSV',delimiter=';')

# %% [markdown]
# ####### Create lists of each race

# %%
# Marrakesh 16 Q
MA16QG1_List = [ma16qg1, w_ma16qg1]
MA16QSuperPole_List = [ma16qsuperpole, w_ma16qsuperpole]
# Marrakesh 16 Race
MA16Race_List = [ma16ranalysis, w_ma16race]
# Marrakesh 17 Q
MA17QG1_List = [ma17qg1, w_ma17qg1]
MA17QG2_List = [ma17qg2, w_ma17qg2]
MA17QG3_List = [ma17qg3, w_ma17qg3]
MA17QG4_List = [ma17qg4, w_ma17qg4]
MA17SuperPole_List = [ma17qsuperpole, w_ma17qsuperpole]
# Marrakesh 17 Race
MA17Race_List = [ma17ranalysis, w_ma17race]

# %%
#COPY THIS CELL
def clean(df1, df2):
  df1[' HOUR'] = pd.to_datetime(df1[' HOUR'])
  df1['DT Elapsed'] = (df1.iloc[0:, 14] - df1.iat[1, 14])
  df1.drop(df1.index[[0,1]])
  df1['DT Elapsed'] = df1['DT Elapsed'].apply(lambda x: abs(x) if pd.notna(x) else None)
  df1.columns = df1.columns.str.replace(' ', '') 

  df2['TIME_UTC_STR'] = pd.to_datetime(df2['TIME_UTC_STR'])
  df2['Elapsed'] = df2.iloc[1:, 1] - df2.iat[0, 1]
  df2['AIR_TEMP'] = df2['AIR_TEMP'].astype(str)
  df2['TRACK_TEMP'] = df2['TRACK_TEMP'].astype(str)
  df2['WIND_SPEED'] = df2['WIND_SPEED'].astype(str)
  df2['AIR_TEMP'] = df2['AIR_TEMP'].str.replace(r'\D','.')
  df2['TRACK_TEMP'] = df2['TRACK_TEMP'].str.replace(r'\D','.')
  df2['WIND_SPEED'] = df2['WIND_SPEED'].str.replace(r'\D','.')

  df2['AIR_TEMP'] = df2['AIR_TEMP'].astype('float')
  df2['TRACK_TEMP'] = df2['TRACK_TEMP'].astype('float')
  df2['WIND_SPEED'] = df2['WIND_SPEED'].astype('float')
  return df1, df2

# %%
#COPY THIS CELL
def mergeweather(df1, df2):
  airtemplist = []
  tracktemplist = []
  windspeedlist = []
  winddirlist = []
  drivers = df1.NUMBER.unique()
  for j in range(len(drivers)):
    driverdf = df1[df1['NUMBER'] == drivers[j]].copy()
    idx = 0
    for i in range(len(driverdf)):
      check = driverdf.iloc[i,-1]
      selection = df2[(df2.iloc[0:, -1] - df2.iat[1, -1]) <= check].copy()
      idxlist = selection.index.tolist()
      selection = selection.iloc[idx-1:]
      avg = selection.mean()
      airtemp = avg['AIR_TEMP']
      tracktemp = avg['TRACK_TEMP']
      windspeed = avg['WIND_SPEED']
      winddir = avg['WIND_DIRECTION']
      airtemplist.append(airtemp)
      tracktemplist.append(tracktemp)
      windspeedlist.append(windspeed)
      winddirlist.append(winddir)
      idx = int(idxlist[-1])


  weatherdict = {'AIR_TEMP':airtemplist,'TRACK_TEMP':tracktemplist,'WIND_SPEED':windspeedlist,'WIND_DIRECTION':winddirlist}
  weatherdf = pd.DataFrame(weatherdict)
  merge = pd.concat([df1,weatherdf],axis=1,ignore_index=False,join='outer')
  df1 = merge.copy()
  return df1

# %%
#COPY THIS CELL
def dropcol(df):
  df.drop(labels=['DRIVER_NUMBER', 'CROSSING_FINISH_LINE_IN_PIT','S1','S1_IMPROVEMENT','S2','S2_IMPROVEMENT','S3','S3_IMPROVEMENT','S1_LARGE','S2_LARGE','S3_LARGE','TOP_SPEED', 'DTElapsed','Unnamed:25'], axis=1, inplace=True)
  return df

# %%
all_files = [MA16QG1_List, 
             MA16QSuperPole_List, 
             MA16Race_List, 
             MA17QG1_List, 
             MA17QG2_List, 
             MA17QG3_List, 
             MA17QG4_List,
             MA17SuperPole_List,
             MA17Race_List]

# %%
#COPY THIS CELL
for l in all_files:
  clean(l[0],l[1])
  l[0] = mergeweather(l[0],l[1])
  l[0] = dropcol(l[0])
  l = [l[0],l[1]]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   app.launch_new_instance()
# ...

# %%
MA16Q_List = [all_files[0][0]]

# %%
MA16SP_List = [all_files[1][0]]

# %%
MA16R_List = [all_files[2][0]]

# %%
MA17Q_List = [all_files[3][0],
              all_files[4][0],
              all_files[5][0],
              all_files[6][0]]

# %%
MA17SP_List = [all_files[7][0]]

# %%
MA17R_List = [all_files[8][0]]

# %%
MA16Q = pd.concat(MA16Q_List,ignore_index=True)
MA16SP = pd.concat(MA16SP_List,ignore_index=True)
MA16R = pd.concat(MA16R_List,ignore_index=True)
MA17Q = pd.concat(MA17Q_List,ignore_index=True)
MA17SP = pd.concat(MA17SP_List,ignore_index=True)
MA17R = pd.concat(MA17R_List,ignore_index=True)

# %%
MA16Q.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/MA16Q.csv")
MA16SP.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/MA16SP.csv")
MA16R.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/MA16R.csv")
MA17Q.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/MA17Q.csv")
MA17SP.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/MA17SP.csv")
MA17R.to_csv("/content/drive/Shared drives/Eco-Cheetah F20 Case Comp/Code/Cleaned CSVs/MA17R.csv")
